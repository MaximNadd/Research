# %%
import tensorflow as tf
import os
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import nibabel as nib
import random
from scipy import ndimage
import time
import datetime

from tensorflow import keras
from tensorflow.keras.layers import Input, Conv3D, MaxPool3D, GlobalAveragePooling3D, Dense, Dropout, BatchNormalization, concatenate
from tensorflow.keras.models import Model, load_model
from keras.callbacks import EarlyStopping, ReduceLROnPlateau, ModelCheckpoint
from keras.utils import plot_model
from keras.metrics import AUC
from sklearn.model_selection import train_test_split
from tensorflow.keras.regularizers import l2
from sklearn.model_selection import train_test_split
from keras.utils import Sequence

# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("maximnaddaf/ct-multi-modal-dataset")

print("Path to dataset files:", path)
# Out:
# Path to dataset files: /kaggle/input/

# %%
def count_directories(path):
    # List all items in the directory and filter for directories
    return len([d for d in os.listdir(path) if os.path.isdir(os.path.join(path, d))])


non_healthy = "/kaggle/input/Processed_CT/CT-23"
healthy = "/kaggle/input/Processed_CT/CT-0"

print(f"Number of directories in non healthy: {count_directories(non_healthy)}")
print(f"Number of directories in healthy: {count_directories(healthy)}")
# Out:
# Number of directories in non healthy: 172
# Number of directories in healthy: 172

# %%
# Function to load a .nii.gz file
def load_nii(file_path):
    return nib.load(file_path).get_fdata()


def rotate(volume):
    # define some rotation angles
    angles = [-20, -10, -5, 5, 10, 20]
    # pick angles at random
    angle = random.choice(angles)
    # rotate volume
    volume = ndimage.rotate(volume, angle, reshape=False)
    volume[volume < 0] = 0
    volume[volume > 1] = 1
    return volume

    augmented_volume = tf.numpy_function(scipy_rotate, [volume], tf.float32)
    return augmented_volume



class MultiModalDataset(Sequence):
    def __init__(self, patient_dirs, labels, batch_size, fold, shuffle=True):
        self.patient_dirs = patient_dirs
        self.labels = labels
        self.batch_size = batch_size
        self.shuffle = shuffle
        self.fold = fold
        self.indices = np.arange(len(self.patient_dirs))
        self.on_epoch_end()

    def __len__(self):
        return int(np.floor(len(self.patient_dirs) / self.batch_size))

    def __getitem__(self, index):
        batch_indices = self.indices[index * self.batch_size:(index + 1) * self.batch_size]
        batch_patient_dirs = [self.patient_dirs[i] for i in batch_indices]
        batch_labels = [self.labels[i] for i in batch_indices]

        # Load modalities
        X = self.__load_modalities(batch_patient_dirs)
        y = np.array(batch_labels)

        X = tuple(tf.convert_to_tensor(x, dtype=tf.float32) for x in X)

        return X, y

    def on_epoch_end(self):
        if self.shuffle:
            np.random.shuffle(self.indices)

    def __load_modalities(self, patient_dirs):
        modalities = {'split_1': [], 'split_2': []}

        for patient_dir in patient_dirs:
            patient_name = os.path.basename(patient_dir)

            split_1_path = os.path.join(patient_dir, 'split_part_1.nii')
            split_2_path = os.path.join(patient_dir, 'split_part_2.nii')

            # Load each modality
            split_1 = load_nii(split_1_path)
            split_2 = load_nii(split_2_path)

            if (self.fold == "train"):
                split_1_augmented = rotate(split_1)
                split_2_augmented = rotate(split_2)

                modalities['split_1'].append(split_1_augmented)
                modalities['split_2'].append(split_2_augmented)

            elif (self.fold == "test"):
                modalities['split_1'].append(split_1)
                modalities['split_2'].append(split_2)


        # Stack the modalities for each patient along the first axis (batch axis)
        X = [
            np.array(modalities['split_1']),
            np.array(modalities['split_2']),
        ]

        return X

# Define the paths to your directories
healthy_dir = healthy
non_healthy_dir = non_healthy

# List all patient directories (assuming each patient has a folder in each group)
healthy_patients = [os.path.join(healthy_dir, f) for f in os.listdir(healthy_dir) if os.path.isdir(os.path.join(healthy_dir, f))]
non_healthy_patients = [os.path.join(non_healthy_dir, f) for f in os.listdir(non_healthy_dir) if os.path.isdir(os.path.join(non_healthy_dir, f))]

# Initialize lists to hold the data and labels
patient_dirs = []  # Will hold paths to the patient directories
labels = []  # Will hold the labels (0 for healthy, 1 for non-healthy)

# Load the data from healthy patients
for patient in healthy_patients:
    patient_dirs.append(patient)
    labels.append(0)  # Label 0 for healthy

# Load the data from non-healthy patients
for patient in non_healthy_patients:
    patient_dirs.append(patient)
    labels.append(1)  # Label 1 for non-healthy

# Convert to NumPy arrays
patient_dirs = np.array(patient_dirs)
labels = np.array(labels)

# Shuffle the data
indices = np.arange(len(patient_dirs))
np.random.shuffle(indices)

patient_dirs = patient_dirs[indices]
labels = labels[indices]

# Split the data into training and testing sets (80/20)
patient_dirs_train, patient_dirs_test, labels_train, labels_test = train_test_split(patient_dirs, labels, test_size=0.2, random_state=42)

# Create the training and testing dataset objects
train_dataset = MultiModalDataset(patient_dirs_train, labels_train, batch_size=4, fold="train", shuffle=True)
test_dataset = MultiModalDataset(patient_dirs_test, labels_test, batch_size=2, fold="test", shuffle=True)

# Check the length of the datasets
print(f"Train Dataset Length: {len(train_dataset)}")
print(f"Test Dataset Length: {len(test_dataset)}")
print(f"Labels Dataset Length: {len(labels)}")

print("\n")

X, y = train_dataset[0]

for modality, data in zip(['split_1', 'split_2'], X):
    print(f"Shape of {modality} modality: {data.shape}")

print(f"label: {y}")
# Out:
# Train Dataset Length: 68
# Test Dataset Length: 34
# Labels Dataset Length: 344
#
#
# Shape of split_1 modality: (4, 224, 224, 25)
# Shape of split_2 modality: (4, 224, 224, 25)
# label: [0 0 0 1]

# %%
def plot_scans_from_dataset(dataset):

    fig = plt.figure(figsize=(20,8))

    for i in range(1):
        scans, label = dataset[i]
        print("Number of scans:", len(scans))
        print("Dimension of CT scan:", scans[0][0].shape)
        print("label=",label[i])
        print("\n")

        ax1 = plt.subplot(1,4,1)
        ax1.imshow(scans[0][0][:,:, scans[0][0].shape[2] // 2], cmap="gray")
        ax1.set_title("Split_1, Middle Slice")
        
        ax2 = plt.subplot(1,4,2)
        ax2.imshow(scans[1][0][:,:, scans[1][0].shape[2] // 2], cmap="gray")
        ax2.set_title("Split_2, Middle Slice")
        
        ax3 = plt.subplot(1,4,3)
        ax3.imshow(scans[0][1][:,:, scans[0][0].shape[2] // 2], cmap="gray")
        ax3.set_title("Split_1, Middle Slice")
        
        ax4 = plt.subplot(1,4,4)
        ax4.imshow(scans[1][1][:,:, scans[1][0].shape[2] // 2], cmap="gray")
        ax4.set_title("Split_1, Middle Slice")

plot_scans_from_dataset(train_dataset)
plot_scans_from_dataset(test_dataset)
# Out:
# Number of scans: 2
# Dimension of CT scan: (224, 224, 25)
# label= 0
#
#
# Number of scans: 2
# Dimension of CT scan: (224, 224, 25)
# label= 1

# %%
def get_model(inputs):
    """Build a 3D convolutional neural network model."""

    x = Conv3D(filters=16, kernel_size=3, activation="relu", padding="same")(inputs)
    x = MaxPool3D(pool_size=2)(x)
    x = BatchNormalization()(x)
    
    x = Conv3D(filters=32, kernel_size=3, activation="relu", padding="same")(x)
    x = MaxPool3D(pool_size=2)(x)
    x = BatchNormalization()(x)
    x = Dropout(0.1)(x)
        
    x = Conv3D(filters=32, kernel_size=3, activation="relu", padding="same")(x)
    x = MaxPool3D(pool_size=2)(x)
    x = BatchNormalization()(x)
    x = Dropout(0.2)(x)

    return x

# %%
tf.random.set_seed(42)

split_1_input = Input(shape=(224, 224, 25, 1))
split_1_model = get_model(split_1_input)

split_2_input = Input(shape=(224, 224, 25, 1))
split_2_model = get_model(split_2_input)


# Concat models and add final block
x = concatenate([split_1_model, split_2_model])

x = GlobalAveragePooling3D()(x)
x = Dense(units=700, activation="relu")(x)
x = Dropout(0.3)(x)

output_layer = Dense(units=1, activation="sigmoid")(x)

# Final model
cnn_model = Model(inputs=[split_1_input, split_2_input], outputs=[output_layer], name="multi3dcnn")


initial_learning_rate = 0.0001
lr_schedule = keras.optimizers.schedules.ExponentialDecay(
    initial_learning_rate, decay_steps=100000, decay_rate=0.96, staircase=False
)

early_stop = EarlyStopping(monitor = 'val_loss',
                           patience = 20, mode = 'min', verbose = 1,
                           restore_best_weights = True)

model_save = ModelCheckpoint(f'3d_image_classification.keras',
                             save_best_only = True,
                             monitor = 'val_loss',
                             mode = 'min', verbose = 1)

# Compile final model
cnn_model.compile(loss='binary_crossentropy',
                  optimizer=keras.optimizers.Adam(learning_rate=lr_schedule),
                  metrics=["accuracy", "AUC"])

# %%
plot_model(cnn_model, show_shapes=True, show_layer_names=True)

# %%
cnn_model.summary()
# Out:
# Model: "multi3dcnn"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)              ┃ Output Shape           ┃        Param # ┃ Connected to           ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)  │ (None, 224, 224, 25,   │              0 │ -                      │
# │                           │ 1)                     │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ input_layer_1             │ (None, 224, 224, 25,   │              0 │ -                      │
# │ (InputLayer)              │ 1)                     │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv3d (Conv3D)           │ (None, 224, 224, 25,   │            448 │ input_layer[0][0]      │
# │                           │ 16)                    │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv3d_3 (Conv3D)         │ (None, 224, 224, 25,   │            448 │ input_layer_1[0][0]    │
# │                           │ 16)                    │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ max_pooling3d             │ (None, 112, 112, 12,   │              0 │ conv3d[0][0]           │
# │ (MaxPooling3D)            │ 16)                    │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ max_pooling3d_3           │ (None, 112, 112, 12,   │              0 │ conv3d_3[0][0]         │
# │ (MaxPooling3D)            │ 16)                    │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization       │ (None, 112, 112, 12,   │             64 │ max_pooling3d[0][0]    │
# │ (BatchNormalization)      │ 16)                    │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_3     │ (None, 112, 112, 12,   │             64 │ max_pooling3d_3[0][0]  │
# │ (BatchNormalization)      │ 16)                    │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv3d_1 (Conv3D)         │ (None, 112, 112, 12,   │         13,856 │ batch_normalization[0… │
# │                           │ 32)                    │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv3d_4 (Conv3D)         │ (None, 112, 112, 12,   │         13,856 │ batch_normalization_3… │
# │                           │ 32)                    │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ max_pooling3d_1           │ (None, 56, 56, 6, 32)  │              0 │ conv3d_1[0][0]         │
# │ (MaxPooling3D)            │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ max_pooling3d_4           │ (None, 56, 56, 6, 32)  │              0 │ conv3d_4[0][0]         │
# │ (MaxPooling3D)            │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_1     │ (None, 56, 56, 6, 32)  │            128 │ max_pooling3d_1[0][0]  │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_4     │ (None, 56, 56, 6, 32)  │            128 │ max_pooling3d_4[0][0]  │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dropout (Dropout)         │ (None, 56, 56, 6, 32)  │              0 │ batch_normalization_1… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dropout_2 (Dropout)       │ (None, 56, 56, 6, 32)  │              0 │ batch_normalization_4… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv3d_2 (Conv3D)         │ (None, 56, 56, 6, 32)  │         27,680 │ dropout[0][0]          │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv3d_5 (Conv3D)         │ (None, 56, 56, 6, 32)  │         27,680 │ dropout_2[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ max_pooling3d_2           │ (None, 28, 28, 3, 32)  │              0 │ conv3d_2[0][0]         │
# │ (MaxPooling3D)            │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ max_pooling3d_5           │ (None, 28, 28, 3, 32)  │              0 │ conv3d_5[0][0]         │
# │ (MaxPooling3D)            │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_2     │ (None, 28, 28, 3, 32)  │            128 │ max_pooling3d_2[0][0]  │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_5     │ (None, 28, 28, 3, 32)  │            128 │ max_pooling3d_5[0][0]  │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dropout_1 (Dropout)       │ (None, 28, 28, 3, 32)  │              0 │ batch_normalization_2… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dropout_3 (Dropout)       │ (None, 28, 28, 3, 32)  │              0 │ batch_normalization_5… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ concatenate (Concatenate) │ (None, 28, 28, 3, 64)  │              0 │ dropout_1[0][0],       │
# │                           │                        │                │ dropout_3[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ global_average_pooling3d  │ (None, 64)             │              0 │ concatenate[0][0]      │
# │ (GlobalAveragePooling3D)  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense (Dense)             │ (None, 700)            │         45,500 │ global_average_poolin… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dropout_4 (Dropout)       │ (None, 700)            │              0 │ dense[0][0]            │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_1 (Dense)           │ (None, 1)              │            701 │ dropout_4[0][0]        │
# └───────────────────────────┴────────────────────────┴────────────────┴────────────────────────┘
#  Total params: 130,809 (510.97 KB)
#  Trainable params: 130,489 (509.72 KB)
#  Non-trainable params: 320 (1.25 KB)

# %%
from tensorflow.keras.callbacks import Callback

class GPUUsageCallback(Callback):
    def __init__(self):
        super().__init__()
        self.peak_gpu_memory_usage = []  # To store memory usage for each epoch

    def on_epoch_end(self, epoch, logs=None):
        # Get the current GPU memory usage
        gpus = tf.config.experimental.list_physical_devices('GPU')
        if gpus:
            device_name = f'GPU:0'
            memory_info = tf.config.experimental.get_memory_info(device_name)
            memory_usage = memory_info['current'] / 1024 / 1024  # Convert bytes to MB

            # Append to the list
            self.peak_gpu_memory_usage.append(memory_usage)

            # Print epoch number and memory usage
            print(f"Epoch {epoch + 1}: GPU Memory Usage = {memory_usage:.2f} MB")

# Assuming you have your model and data
gpu_usage = GPUUsageCallback()

# %%
start_time = time.time()
history = cnn_model.fit(train_dataset, validation_data=test_dataset, epochs=55, callbacks=[model_save, early_stop, gpu_usage])
end_time = time.time()
# Out:
# Epoch 1/55
# /usr/local/lib/python3.10/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:122: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 13s/step - AUC: 0.6487 - accuracy: 0.6154 - loss: 0.6761
# /usr/local/lib/python3.10/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:122: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1: val_loss improved from inf to 0.85913, saving model to 3d_image_classification.keras
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 998s 14s/step - AUC: 0.6488 - accuracy: 0.6150 - loss: 0.6760 - val_AUC: 0.6491 - val_accuracy: 0.4412 - val_loss: 0.8591
# Epoch 2/55
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 14s/step - AUC: 0.7438 - accuracy: 0.6958 - loss: 0.6348
# Epoch 2: val_loss did not improve from 0.85913
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1032s 15s/step - AUC: 0.7431 - accuracy: 0.6954 - loss: 0.6350 - val_AUC: 0.6312 - val_accuracy: 0.4559 - val_loss: 1.4061
# Epoch 3/55
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 14s/step - AUC: 0.6746 - accuracy: 0.6314 - loss: 0.6470
# Epoch 3: val_loss did not improve from 0.85913
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1041s 15s/step - AUC: 0.6747 - accuracy: 0.6313 - loss: 0.6470 - val_AUC: 0.6295 - val_accuracy: 0.4559 - val_loss: 1.6655
# Epoch 4/55
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 14s/step - AUC: 0.6745 - accuracy: 0.6082 - loss: 0.6383
# Epoch 4: val_loss did not improve from 0.85913
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1041s 15s/step - AUC: 0.6752 - accuracy: 0.6087 - loss: 0.6381 - val_AUC: 0.6988 - val_accuracy: 0.4559 - val_loss: 2.1219
# Epoch 5/55
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 14s/step - AUC: 0.6609 - accuracy: 0.6432 - loss: 0.6497
# Epoch 5: val_loss did not improve from 0.85913
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1035s 15s/step - AUC: 0.6612 - accuracy: 0.6432 - loss: 0.6496 - val_AUC: 0.6970 - val_accuracy: 0.4559 - val_loss: 2.1201
# Epoch 6/55
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 14s/step - AUC: 0.7764 - accuracy: 0.7230 - loss: 0.5766
# Epoch 6: val_loss did not improve from 0.85913
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1034s 15s/step - AUC: 0.7756 - accuracy: 0.7220 - loss: 0.5771 - val_AUC: 0.7833 - val_accuracy: 0.4559 - val_loss: 2.0188
# Epoch 7/55
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 14s/step - AUC: 0.6267 - accuracy: 0.5782 - loss: 0.6646
# Epoch 7: val_loss did not improve from 0.85913
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1027s 15s/step - AUC: 0.6279 - accuracy: 0.5792 - loss: 0.6640 - val_AUC: 0.7794 - val_accuracy: 0.4559 - val_loss: 1.8548
# Epoch 8/55
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 14s/step - AUC: 0.7042 - accuracy: 0.6343 - loss: 0.6199
# Epoch 8: val_loss did not improve from 0.85913
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1044s 15s/step - AUC: 0.7043 - accuracy: 0.6347 - loss: 0.6199 - val_AUC: 0.7702 - val_accuracy: 0.4412 - val_loss: 1.4845
# Epoch 9/55
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 14s/step - AUC: 0.7592 - accuracy: 0.7279 - loss: 0.5853
# Epoch 9: val_loss did not improve from 0.85913
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1031s 15s/step - AUC: 0.7593 - accuracy: 0.7277 - loss: 0.5852 - val_AUC: 0.7890 - val_accuracy: 0.4559 - val_loss: 1.3398
# Epoch 10/55
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 14s/step - AUC: 0.7577 - accuracy: 0.6928 - loss: 0.5881
# Epoch 10: val_loss did not improve from 0.85913
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1040s 15s/step - AUC: 0.7574 - accuracy: 0.6925 - loss: 0.5884 - val_AUC: 0.7947 - val_accuracy: 0.4706 - val_loss: 0.9686
# Epoch 11/55
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 14s/step - AUC: 0.7585 - accuracy: 0.6952 - loss: 0.5865
# Epoch 11: val_loss did not improve from 0.85913
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1027s 15s/step - AUC: 0.7588 - accuracy: 0.6952 - loss: 0.5863 - val_AUC: 0.7895 - val_accuracy: 0.4706 - val_loss: 1.1810
# Epoch 12/55
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 14s/step - AUC: 0.7725 - accuracy: 0.7334 - loss: 0.5771
# Epoch 12: val_loss improved from 0.85913 to 0.82726, saving model to 3d_image_classification.keras
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1034s 15s/step - AUC: 0.7726 - accuracy: 0.7332 - loss: 0.5770 - val_AUC: 0.7537 - val_accuracy: 0.5000 - val_loss: 0.8273
# Epoch 13/55
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 14s/step - AUC: 0.7929 - accuracy: 0.7025 - loss: 0.5688
# Epoch 13: val_loss did not improve from 0.82726
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1041s 15s/step - AUC: 0.7926 - accuracy: 0.7024 - loss: 0.5690 - val_AUC: 0.7746 - val_accuracy: 0.4853 - val_loss: 0.9490
# Epoch 14/55
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 14s/step - AUC: 0.7952 - accuracy: 0.6958 - loss: 0.5586
# Epoch 14: val_loss did not improve from 0.82726
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1055s 15s/step - AUC: 0.7948 - accuracy: 0.6959 - loss: 0.5589 - val_AUC: 0.7977 - val_accuracy: 0.5000 - val_loss: 0.8706
# Epoch 15/55
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 14s/step - AUC: 0.8102 - accuracy: 0.7203 - loss: 0.5416
# Epoch 15: val_loss did not improve from 0.82726
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1032s 15s/step - AUC: 0.8100 - accuracy: 0.7204 - loss: 0.5417 - val_AUC: 0.8043 - val_accuracy: 0.5000 - val_loss: 1.0542
# Epoch 16/55
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 14s/step - AUC: 0.7025 - accuracy: 0.6564 - loss: 0.6281
# Epoch 16: val_loss did not improve from 0.82726
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1039s 15s/step - AUC: 0.7037 - accuracy: 0.6573 - loss: 0.6271 - val_AUC: 0.7947 - val_accuracy: 0.5000 - val_loss: 1.0110
# Epoch 17/55
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 14s/step - AUC: 0.7727 - accuracy: 0.7184 - loss: 0.5763
# Epoch 17: val_loss did not improve from 0.82726
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1027s 15s/step - AUC: 0.7726 - accuracy: 0.7182 - loss: 0.5764 - val_AUC: 0.7921 - val_accuracy: 0.4559 - val_loss: 1.1764
# Epoch 18/55
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 14s/step - AUC: 0.7535 - accuracy: 0.6954 - loss: 0.5893
# Epoch 18: val_loss did not improve from 0.82726
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1051s 15s/step - AUC: 0.7539 - accuracy: 0.6958 - loss: 0.5890 - val_AUC: 0.7873 - val_accuracy: 0.4853 - val_loss: 1.0636
# Epoch 19/55
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 14s/step - AUC: 0.7999 - accuracy: 0.7087 - loss: 0.5552
# Epoch 19: val_loss did not improve from 0.82726
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1031s 15s/step - AUC: 0.7995 - accuracy: 0.7085 - loss: 0.5555 - val_AUC: 0.7811 - val_accuracy: 0.4853 - val_loss: 1.2726
# Epoch 20/55
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 14s/step - AUC: 0.7960 - accuracy: 0.7346 - loss: 0.5502
# Epoch 20: val_loss did not improve from 0.82726
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1014s 15s/step - AUC: 0.7959 - accuracy: 0.7345 - loss: 0.5503 - val_AUC: 0.7825 - val_accuracy: 0.4706 - val_loss: 1.1837
# Epoch 21/55
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 14s/step - AUC: 0.7798 - accuracy: 0.7042 - loss: 0.5674
# Epoch 21: val_loss did not improve from 0.82726
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1008s 15s/step - AUC: 0.7801 - accuracy: 0.7043 - loss: 0.5671 - val_AUC: 0.7890 - val_accuracy: 0.4853 - val_loss: 1.2533
# Epoch 22/55
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 14s/step - AUC: 0.7954 - accuracy: 0.7174 - loss: 0.5404
# Epoch 22: val_loss did not improve from 0.82726
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1045s 15s/step - AUC: 0.7954 - accuracy: 0.7174 - loss: 0.5406 - val_AUC: 0.7942 - val_accuracy: 0.4853 - val_loss: 1.3071
# Epoch 23/55
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 14s/step - AUC: 0.8067 - accuracy: 0.7037 - loss: 0.5379
# Epoch 23: val_loss did not improve from 0.82726
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1008s 15s/step - AUC: 0.8067 - accuracy: 0.7038 - loss: 0.5379 - val_AUC: 0.8013 - val_accuracy: 0.5294 - val_loss: 1.1539
# Epoch 24/55
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 14s/step - AUC: 0.7582 - accuracy: 0.6856 - loss: 0.5837
# Epoch 24: val_loss did not improve from 0.82726
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1005s 15s/step - AUC: 0.7587 - accuracy: 0.6858 - loss: 0.5834 - val_AUC: 0.7759 - val_accuracy: 0.5000 - val_loss: 0.8877
# Epoch 25/55
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 14s/step - AUC: 0.8594 - accuracy: 0.7855 - loss: 0.4918
# Epoch 25: val_loss did not improve from 0.82726
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1047s 15s/step - AUC: 0.8589 - accuracy: 0.7848 - loss: 0.4922 - val_AUC: 0.7742 - val_accuracy: 0.5000 - val_loss: 1.3459
# Epoch 26/55
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 14s/step - AUC: 0.8175 - accuracy: 0.7052 - loss: 0.5339
# Epoch 26: val_loss did not improve from 0.82726
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1034s 15s/step - AUC: 0.8174 - accuracy: 0.7056 - loss: 0.5340 - val_AUC: 0.7690 - val_accuracy: 0.4706 - val_loss: 1.3604
# Epoch 27/55
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 14s/step - AUC: 0.8094 - accuracy: 0.7552 - loss: 0.5420
# Epoch 27: val_loss did not improve from 0.82726
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1014s 15s/step - AUC: 0.8095 - accuracy: 0.7551 - loss: 0.5418 - val_AUC: 0.7951 - val_accuracy: 0.4853 - val_loss: 1.4120
# Epoch 28/55
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 14s/step - AUC: 0.8149 - accuracy: 0.7414 - loss: 0.5318
# Epoch 28: val_loss did not improve from 0.82726
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1044s 15s/step - AUC: 0.8149 - accuracy: 0.7417 - loss: 0.5319 - val_AUC: 0.7376 - val_accuracy: 0.4853 - val_loss: 1.2647
# Epoch 29/55
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 14s/step - AUC: 0.7802 - accuracy: 0.6796 - loss: 0.5503
# Epoch 29: val_loss did not improve from 0.82726
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1016s 15s/step - AUC: 0.7809 - accuracy: 0.6800 - loss: 0.5499 - val_AUC: 0.8213 - val_accuracy: 0.4853 - val_loss: 1.4799
# Epoch 30/55
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 14s/step - AUC: 0.8215 - accuracy: 0.7192 - loss: 0.5280
# Epoch 30: val_loss did not improve from 0.82726
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1041s 15s/step - AUC: 0.8213 - accuracy: 0.7192 - loss: 0.5283 - val_AUC: 0.8079 - val_accuracy: 0.4706 - val_loss: 1.8462
# Epoch 31/55
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 14s/step - AUC: 0.8041 - accuracy: 0.7373 - loss: 0.5351
# Epoch 31: val_loss did not improve from 0.82726
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1061s 15s/step - AUC: 0.8044 - accuracy: 0.7373 - loss: 0.5349 - val_AUC: 0.8021 - val_accuracy: 0.5000 - val_loss: 1.2551
# Epoch 32/55
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 14s/step - AUC: 0.8561 - accuracy: 0.7853 - loss: 0.4862
# Epoch 32: val_loss did not improve from 0.82726
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1024s 15s/step - AUC: 0.8558 - accuracy: 0.7848 - loss: 0.4865 - val_AUC: 0.7680 - val_accuracy: 0.4559 - val_loss: 1.6394
# Epoch 32: early stopping
# Restoring model weights from the end of the best epoch: 12.

# %%
print(f"Training time: {end_time - start_time:.2f} seconds")
# Out:
# Training time: 33023.57 seconds

# %%
import pandas as pd

history_df = pd.DataFrame(history.history)

# Set up the figure for the plots
fig, axes = plt.subplots(1, 2, figsize=(15, 10), sharex=True, sharey=True)

# Plot validation metrics (val_AUC, val_accuracy, val_loss)
axes[0].plot(history_df['val_AUC'], label='AUC (Val)', color='blue')
axes[0].plot(history_df['val_accuracy'], label='Accuracy (Val)', color='green')
axes[0].plot(history_df['val_loss'], label='Loss (Val)', color='red')

axes[0].set_title('Validation Metrics')
axes[0].set_xlabel('Epochs')
axes[0].set_ylabel('Metric Value')
axes[0].legend()

# Plot training metrics (AUC, accuracy, loss)
axes[1].plot(history_df['AUC'], label='AUC (Train)', color='blue')
axes[1].plot(history_df['accuracy'], label='Accuracy (Train)', color='green')
axes[1].plot(history_df['loss'], label='Loss (Train)', color='red')

axes[1].set_title('Training Metrics')
axes[1].set_xlabel('Epochs')
axes[1].set_ylabel('Metric Value')
axes[1].legend()

plt.tight_layout()
plt.show()

# %%
test_loss, test_accuracy, test_auc = cnn_model.evaluate(test_dataset)

# Store evaluation metrics for later plotting
eval_metrics = {
    'Test Loss': test_loss,
    'Test Accuracy': test_accuracy,
    'Test AUC': test_auc
}

# Create a bar plot to visualize evaluation metrics
plt.figure(figsize=(10, 6))
plt.bar(eval_metrics.keys(), eval_metrics.values(), color=['red', 'blue', 'green'])
plt.title('Model Evaluation Metrics')
plt.ylabel('Metric Value')
plt.show()
# Out:
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 63s 2s/step - AUC: 0.8032 - accuracy: 0.5078 - loss: 0.8479

# %%
gpu_memory_usage = gpu_usage.peak_gpu_memory_usage  # List of GPU memory usage for each epoch
epochs = list(range(1, len(gpu_memory_usage) + 1))

# Plotting the GPU memory usage over epochs
plt.figure(figsize=(10, 6))
plt.plot(epochs, gpu_memory_usage, marker='o', color='b', label='GPU Memory Usage (MB)')

# Add labels and title
plt.xlabel('Epochs', fontsize=12)
plt.ylabel('GPU Memory Usage (MB)', fontsize=12)
plt.title('Training GPU Memory Usage Per Epoch', fontsize=14)

# Display the grid and legend
plt.grid(True)
plt.legend()

# Show the plot
plt.show()
